# %%
# !pip install -q PyPDF2 langchain openai chromadb tiktoken

# %%
# from langchain.vectorstores import Chroma
# from langchain_openai import OpenAIEmbeddings
# from langchain.text_splitter import RecursiveCharacterTextSplitter
# from langchain.chains import RetrievalQA
# from langchain.document_loaders import TextLoader, DirectoryLoader
# from langchain_openai import ChatOpenAI
# from langchain_openai import OpenAI

import PyPDF2
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.document_loaders import TextLoader, DirectoryLoader
from langchain.vectorstores import Chroma

# %%
file_path = "/content/DSA.txt"

# %%
loader = TextLoader(file_path)
documents = loader.load()

# %%
documents[0].page_content
# Out:
# 'Sure, here are 100 multiple-choice questions (MCQs) on Data Structures and Algorithms along with their answers:\n\n1. What is the time complexity of accessing an element in an array?\n   a) O(1)\n   b) O(log n)\n   c) O(n)\n   d) O(n^2)\n   \n   Answer: a) O(1)\n\n2. Which data structure uses LIFO (Last In First Out) principle?\n   a) Queue\n   b) Stack\n   c) Linked List\n   d) Tree\n   \n   Answer: b) Stack\n\n3. In a binary search tree, which traversal visits the nodes in non-decreasing order?\n   a) Pre-order\n   b) Post-order\n   c) In-order\n   d) Level-order\n   \n   Answer: c) In-order\n\n4. Which sorting algorithm has the best time complexity in the worst-case scenario?\n   a) Bubble Sort\n   b) Insertion Sort\n   c) Quick Sort\n   d) Merge Sort\n   \n   Answer: d) Merge Sort\n\n5. What is the time complexity of searching an element in a binary search tree?\n   a) O(1)\n   b) O(log n)\n   c) O(n)\n   d) O(n^2)\n   \n   Answer: b) O(log n)\n\n6. Which of the following data structures allows rapid random access to elements?\n   a) Linked List\n   b) Queue\n   c) Stack\n   d) Array\n   \n   Answer: d) Array\n\n7. Which algorithm is used to find the shortest path in a weighted graph?\n   a) Depth-First Search (DFS)\n   b) Breadth-First Search (BFS)\n   c) Dijkstra\'s Algorithm\n   d) Prim\'s Algorithm\n   \n   Answer: c) Dijkstra\'s Algorithm\n\n8. Which of the following data structures is best suited for implementing a recursive algorithm?\n   a) Array\n   b) Stack\n   c) Queue\n   d) Linked List\n   \n   Answer: b) Stack\n\n9. Which of the following is not a stable sorting algorithm?\n   a) Bubble Sort\n   b) Merge Sort\n   c) Quick Sort\n   d) Insertion Sort\n   \n   Answer: c) Quick Sort\n\n10. What data structure is typically used for implementing a priority queue?\n    a) Stack\n    b) Queue\n    c) Heap\n    d) Linked List\n    \n    Answer: c) Heap\n\n11. Which traversal technique of a binary tree visits the root node first, then left subtree, and finally right subtree?\n    a) Pre-order\n    b) In-order\n    c) Post-order\n    d) Level-order\n    \n    Answer: a) Pre-order\n\n12. Which sorting algorithm is known for its best-case time complexity of O(n)?\n    a) Bubble Sort\n    b) Insertion Sort\n    c) Quick Sort\n    d) Merge Sort\n    \n    Answer: b) Insertion Sort\n\n13. Which data structure is typically used to implement a hash table?\n    a) Array\n    b) Linked List\n    c) Stack\n    d) Queue\n    \n    Answer: a) Array\n\n14. Which algorithm is used for finding the strongly connected components in a directed graph?\n    a) Dijkstra\'s Algorithm\n    b) Floyd-Warshall Algorithm\n    c) Prim\'s Algorithm\n    d) Kosaraju\'s Algorithm\n    \n    Answer: d) Kosaraju\'s Algorithm\n\n15. Which data structure is typically used for reversing a list efficiently?\n    a) Stack\n    b) Queue\n    c) Linked List\n    d) Array\n    \n    Answer: c) Linked List\n\n16. Which of the following is not a method for resolving collisions in hash tables?\n    a) Chaining\n    b) Linear Probing\n    c) Quadratic Probing\n    d) Traversing\n    \n    Answer: d) Traversing\n\n17. Which searching algorithm requires the input array to be sorted?\n    a) Linear Search\n    b) Binary Search\n    c) Depth-First Search\n    d) Breadth-First Search\n    \n    Answer: b) Binary Search\n\n18. Which of the following is a non-linear data structure?\n    a) Array\n    b) Linked List\n    c) Queue\n    d) Tree\n    \n    Answer: d) Tree\n\n19. Which sorting algorithm has the worst time complexity in the worst-case scenario?\n    a) Bubble Sort\n    b) Insertion Sort\n    c) Quick Sort\n    d) Selection Sort\n    \n    Answer: c) Quick Sort\n\n20. Which traversal technique of a binary tree visits the left subtree, then the right subtree, and finally the root node?\n    a) Pre-order\n    b) In-order\n    c) Post-order\n    d) Level-order\n    \n    Answer: c) Post-order\n\n21. Which algorithm is used to find the minimum spanning tree of a g ...

# %%
text_list = []
source_list = []

text_list.append(documents[0].page_content)
source_list.append(file_path.split("/")[-1])

# %%
file_path.split("/")[-1]
# Out:
# 'DSA.txt'

# %%
text_list
# Out:
# ['Sure, here are 100 multiple-choice questions (MCQs) on Data Structures and Algorithms along with their answers:\n\n1. What is the time complexity of accessing an element in an array?\n   a) O(1)\n   b) O(log n)\n   c) O(n)\n   d) O(n^2)\n   \n   Answer: a) O(1)\n\n2. Which data structure uses LIFO (Last In First Out) principle?\n   a) Queue\n   b) Stack\n   c) Linked List\n   d) Tree\n   \n   Answer: b) Stack\n\n3. In a binary search tree, which traversal visits the nodes in non-decreasing order?\n   a) Pre-order\n   b) Post-order\n   c) In-order\n   d) Level-order\n   \n   Answer: c) In-order\n\n4. Which sorting algorithm has the best time complexity in the worst-case scenario?\n   a) Bubble Sort\n   b) Insertion Sort\n   c) Quick Sort\n   d) Merge Sort\n   \n   Answer: d) Merge Sort\n\n5. What is the time complexity of searching an element in a binary search tree?\n   a) O(1)\n   b) O(log n)\n   c) O(n)\n   d) O(n^2)\n   \n   Answer: b) O(log n)\n\n6. Which of the following data structures allows rapid random access to elements?\n   a) Linked List\n   b) Queue\n   c) Stack\n   d) Array\n   \n   Answer: d) Array\n\n7. Which algorithm is used to find the shortest path in a weighted graph?\n   a) Depth-First Search (DFS)\n   b) Breadth-First Search (BFS)\n   c) Dijkstra\'s Algorithm\n   d) Prim\'s Algorithm\n   \n   Answer: c) Dijkstra\'s Algorithm\n\n8. Which of the following data structures is best suited for implementing a recursive algorithm?\n   a) Array\n   b) Stack\n   c) Queue\n   d) Linked List\n   \n   Answer: b) Stack\n\n9. Which of the following is not a stable sorting algorithm?\n   a) Bubble Sort\n   b) Merge Sort\n   c) Quick Sort\n   d) Insertion Sort\n   \n   Answer: c) Quick Sort\n\n10. What data structure is typically used for implementing a priority queue?\n    a) Stack\n    b) Queue\n    c) Heap\n    d) Linked List\n    \n    Answer: c) Heap\n\n11. Which traversal technique of a binary tree visits the root node first, then left subtree, and finally right subtree?\n    a) Pre-order\n    b) In-order\n    c) Post-order\n    d) Level-order\n    \n    Answer: a) Pre-order\n\n12. Which sorting algorithm is known for its best-case time complexity of O(n)?\n    a) Bubble Sort\n    b) Insertion Sort\n    c) Quick Sort\n    d) Merge Sort\n    \n    Answer: b) Insertion Sort\n\n13. Which data structure is typically used to implement a hash table?\n    a) Array\n    b) Linked List\n    c) Stack\n    d) Queue\n    \n    Answer: a) Array\n\n14. Which algorithm is used for finding the strongly connected components in a directed graph?\n    a) Dijkstra\'s Algorithm\n    b) Floyd-Warshall Algorithm\n    c) Prim\'s Algorithm\n    d) Kosaraju\'s Algorithm\n    \n    Answer: d) Kosaraju\'s Algorithm\n\n15. Which data structure is typically used for reversing a list efficiently?\n    a) Stack\n    b) Queue\n    c) Linked List\n    d) Array\n    \n    Answer: c) Linked List\n\n16. Which of the following is not a method for resolving collisions in hash tables?\n    a) Chaining\n    b) Linear Probing\n    c) Quadratic Probing\n    d) Traversing\n    \n    Answer: d) Traversing\n\n17. Which searching algorithm requires the input array to be sorted?\n    a) Linear Search\n    b) Binary Search\n    c) Depth-First Search\n    d) Breadth-First Search\n    \n    Answer: b) Binary Search\n\n18. Which of the following is a non-linear data structure?\n    a) Array\n    b) Linked List\n    c) Queue\n    d) Tree\n    \n    Answer: d) Tree\n\n19. Which sorting algorithm has the worst time complexity in the worst-case scenario?\n    a) Bubble Sort\n    b) Insertion Sort\n    c) Quick Sort\n    d) Selection Sort\n    \n    Answer: c) Quick Sort\n\n20. Which traversal technique of a binary tree visits the left subtree, then the right subtree, and finally the root node?\n    a) Pre-order\n    b) In-order\n    c) Post-order\n    d) Level-order\n    \n    Answer: c) Post-order\n\n21. Which algorithm is used to find the minimum spanning tree of a  ...

# %%
OPENAI_API_KAY = "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"
embeddings = OpenAIEmbeddings(openai_api_key = OPENAI_API_KAY)
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x7c4199723100>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x7c4199721870>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base=None, openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='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', openai_organization=None, allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None)

# %%
vector_store = Chroma.from_texts(text_list, embeddings, metadatas = [{"source" : s} for s in source_list])

# %%
retriever = vector_store.as_retriever()
retriever.search_kwargs = {"k" : 2}

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['Chroma', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x7c419972cf10>, search_kwargs={'k': 2})
